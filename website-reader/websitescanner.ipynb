# %%
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI
# Load environment variables

# Load environment variables

# Load environment variables in a file called .env

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Nice to meet you, and thanks for saying hi.\n\nI’m here to help with whatever you need—questions, writing, coding, planning, learning something new, or just chatting. If you tell me a bit about your interests or a goal, I can tailor things for you.\n\nQuick ideas for starting:\n- Explain a topic in simple terms\n- Help draft an email, essay, resume, or message\n- Plan a project, study schedule, or trip\n- Debug code or understand programming concepts\n- Brainstorm ideas for a story, video, or game\n- Play a quick game or trivia\n\nWhat would you like to do first? If you want, you can also tell me your name or something you’re curious about.'

# %%
ed = fetch_website_contents("https://hyland.com")
print(ed)
# Out:
# Hyland  | Content Services | Enterprise Content Management
# Skip to content
# Community
# Contact us
# English
# EN
# Português
# PT
# English
# EN
# Français
# FR
# Deutsch
# DE
# 日本語
# 日本語
# Español
# ES
# Search
# Toggle mobile navigation
# Search
# PLATFORM
# PLATFORM
# Platform
# Enterprise AI
# Agentic Document Processing
# Process Automation
# Content Management
# Digital Asset Management
# Governance
# Application Development
# Systems Integrations
# Collaboration
# Cloud
# PLATFORM
# Content Innovation Cloud™
# Harness the power of a unified content, process and application intelligence platform to unlock the value of enterprise content.
# Learn more
# Enterprise AI
# Agentic Document Processing
# Process Automation
# Content Management
# Digital Asset Management
# Insert your title here
# Governance
# Application Development
# Insert your title here
# Systems Integrations
# Collaboration
# Insert your title here
# Cloud
# Close menu
# SOLUTIONS
# SOLUTIONS
# Solutions Overview
# By Industry
# By Department
# Services
# Technical Support
# All Products
# SOLUTIONS
# Intelligent document processing
# Automate your document-centric processes with AI-powered document capture, separation, classification, extraction and enrichment.
# Learn about Hyland IDP
# By Industry
# Industries Overview
# Healthcare
# Financial Services
# Government
# Insurance
# Education
# Media & Entertainment
# Manufacturing
# CPG & Retail
# Other Industries
# Industries
# It's your unique digital evolution … but you don't have to face it alone. We understand the landscape of your industry and the unique needs of the people you serve.
# Overview of industries
# By Department
# Departments Overview
# Accounting & Finance
# Human Resources
# Legal
# Departments
# Countless teams and departments have transformed the way they work in accounting, HR, legal and more with Hyland solutions.
# Overview of departments
# Services
# Services Overview
# Education Services
# Implementation Services
# Managed Services
# Consulting Services
# Data Conversion Services
# Services
# We are committed to helping you maximize your technology investment so you can best serve your customers.
# Overview of services
# Technical Support
# Insert your title here
# All Products
# Close menu
# CUSTOMERS
# CUSTOMERS
# Customers Overview
# Case Studies
# CUSTOMERS
# CommunityLIVE 2026
# Get ready to take your knowledge of AI, enterprise agents and intelligent automation to the next level.
# Register now
# Case Studies
# Close menu
# PARTNERS
# PARTNERS
# Partner Program
# Become a Partner
# Find a Partner
# Partner Resources
# PARTNERS
# Partners
# Our exclusive partner programs combine our strengths with yours to create better experiences through content services.
# Overview of partners
# Become a Partner
# Find a Partner
# Partner Resources
# Close menu
# RESOURCES
# RESOURCES
# Resources Overview
# Analyst Reports
# Articles
# Downloads
# Events
# Product Releases
# Terminology
# Webinars
# Resource Center
# RESOURCES
# Get monthly insights
# Join The Shift newsletter for the latest strategies and expert tips from industry leaders. Discover actionable steps to stay innovative.
# Register now
# Analyst Reports
# Articles
# Articles
# Downloads
# Events
# Product News
# Terminology
# Webinars
# Resource Center
# Close menu
# COMPANY
# COMPANY
# Overview of Hyland
# About
# Why Hyland?
# Newsroom
# Careers
# COMPANY
# Company
# Hyland connects your content and systems so you can forge stronger connections with the people who matter most.
# Learn about Hyland
# About
# About Overview
# History
# Corporate Responsibility
# Acquisitions
# Executive Team
# Locations
# Awards and accolades
# Why choose Hyland?
# With our modern, open and cloud-native platforms, you can build strong connections and keep evolving.
# Dig deeper
# Why Hyland?
# Newsroom
# Careers
# Close menu
# Request a demo
# Unlock the
# power
# of your content
# Connect your enterprise content with our AI-enabled solutions — deliver insights, automate processes and fuel innovation to drive meaningful impact for your business.
# Introducing Hyland Content Innovation Cloud™
# The platform to power content innovation
# Content Innovation Cloud harnesses the power of AI and enables organizations to unlock the full value of their content, processes and applications.
# Content Innovation
# Cloud
# Realize the full potential of your unstructured data
# Explore the capabilities of Content Innovation Cloud
# Harness the power of a unified content, process and application intelligence platform to realize the full potential of your unstructured data.
# Content intelligence
# Leverage AI to unlock the full potential of enterprise content and transform the way you work.
# Agentic Document Processing
# Not only can AI agents autonomously handle exceptions during all stages of document capture and data extraction, but they can also help extend automation downstream and handle the larger business process.
# Process automation
# Embrace a system that efficiently automates processes by helping teams work faster with the best information.
# Content management
# Organize and optimize all content and assets across the entire organization.
# Governance
# Secure enterprise content and improve processes that simplify compliance and risk mitigation.
# Application development
# Take Hyland solutions further with simplified app building and the ability to rapidly customize solutions.
# Systems integration
# Easily connect your business applications and systems to relevant content.
# Collaboration
# Drive efficiency gains and improve data security with enterprise-grade collaboration features.
# Content-tailored cloud architecture
# Manage your content in the cloud for maximum scalability, security, compliance and data accuracy.
# Leading enterprises fuel their innovations with Hyland
# More than half of Fortune 100 companies trust Hyland products and solutions to seamlessly integrate their content, data and processes.
# Transformative innovation from anyone, anywhere
# When enterprise content is the engine of change, there is truly no limit to where you can go.
# Why Hyland?
# More than half of the Fortune 100 use Hyland solutions to maximize their content value and processes. Join those leaders and more in today’s era of intelligent content management.
# Drive content intelligence
# Smart, connected content delivered with native automation leads to better decision-making throughout the entire content lifecycle.
# Stay agile
# Empower your people to meet evolving expectations with Hyland’s future-adaptive, cloud-enabled technology.
# Integrate across the enterprise
# Our configurable, connectable and scalable solutions enable automation and help you optimize business systems and process workflows.
# Work with an industry leader
# Hyland is a recognized leader in content management, relying on a culture of innovation, longstanding partnerships and a deep understanding of our customers' industries.
# Your industry, our experts
# Only Hyland has the deep vertical expertise to build partnerships based on real-world understanding of your industry.
# Healthcare
# Financial services
# Insurance
# Government
# Education
# Media & entertainment
# CPG & retail
# Other industries
# Healthcare solutions
# Payers
# Unite all the content you need from the core systems you use every day. Automate workflows, eliminate information silos and improve the member experience.
# Clinical care
# Give providers and patients a complete view of all relevant content by streamlining patient records, patient consent, enterprise imaging and patient portals.
# Enterprise and diagnostic medical imaging
# Frictionless system integrations, advanced AI and machine learning help modernize your imaging strategy and drive better, faster decision-making.
# Back-office solutions
# Reduce costs and enhance efficiency of critical behind-the-scenes teams by optimizing administration, information management, collaboration and security.
# Explore solutions for healthcare
# Solutions for financial services organizations
# Banking and credit unions
# Meet audit and compliance requirements, speed fraud investigations with intelligent tech, modernize your lending process and meet customers where they are.
# Lending
# Enhance the personal experiences of your customers or members by digitizing and streamlining workflows, from communications to electronic signature.
# Wealth management
# Modernize your business and its processes with automation that embraces cloud-native and open-source technologies for better customer results.
# Explore financial services solutions
# Insurance solutions
# Claims management
# Embrace a core system to centralize all claims information and simplify content management, from accessing to sharing and automating processes.
# Underwriting
# Streamline underwriting with intelligent case management, complete views of relevant content and smart workflows that drive fast, data-based decisions.
# Policy administration
# Provide the excellent service your customers expect with intelligent, automated communications and mobile-friendly online forms.
# Explore solutions for insurance
# Solutions for government
# Secure electronic records management
# Automate the records life cycle from capture to disposition. Hyland’s Alfresco solution is the only platform certified to the DOD 5015.02 Chapter 3 standard.
# Meet global compliance standards
# Stay compliant: Meet all your standards, including ISO 15489, ISO 16175, FOIA, U.S. DOD 5015.02 CH2 and CH3, EgovG, and MoReq.
# Constituent services
# Modernize your public-facing systems with technology and citizen portals for any  department, including public assistance, licenses and permits, FOIA request management and more.
# Explore solutions for government
# Education solutions
# Admissions
# Automate the capture and routing of applications for faster, more accurate decisions. Eliminate slow workflows by scanning paper upon receipt.
# Financial aid
# Send out financial aid packages faster by capturing key data from verification documents and automating the data into your SI or financial system.
# Registrar
# Automate transcript capture and evaluation to speed up the consideration process, so your offers go out sooner and prospective students aren’t left wondering.
# Student advising
# Unite student information into one single source of truth, so the people who need to store and access data can do so quickly and easily.
# Explore solutions for education
# Media & entertainment solutions
# Digital asset management
# Leverage automated tagging and smart, centralized storage for rich media like images, video and documents.
# Back-office solutions
# Bring all your data together to use intelligent automation and customizable workflows in HR, accounting and finance, and legal departments.
# Explore media & entertainment solutions
# CPG & retail solutions
# Automation
# Automate your back-office processes, from HR to AP, and execute more quickly and with fewer errors than manual- or paper-based processes.
# Product information unification
# Connect data from procurement, accounting and warehouse management systems to accelerate downstream processes.
# Compliance
# Meet your compliance goals with a secure, auditable content management system that ensures regulatory demands are enforced.
# Explore solutions for CPG & retail
# Solutions for any industry
# Industry-agnostic solutions
# Hyland’s open-source and customizable solutions serve many industries. Whether listed here or not, our team can deliver effective and transformative solutions for any organization.
# Construction
# Mining
# Oil and gas
# Publishing
# Transportation and logistics
# Explore solutions for any area
# L'Oréal
# L’Oréal leverages Hyland’s Nuxeo Platform to empower 6,000 global users to manage and deliver value from its diverse brand portfolio, encompassing 7 million documents.
# Read the Case study
# Liberty Mutual Insurance
# Read the Case study
# Toyota Financial Services
# Read the Case study
# Newsroom
# News
# Hyland introduces new agentic and AI‑driven innovations to turn enterprise content into action
# Hyland’s latest technology updates embed content intelligence directly into core systems to drive governed automation across regulated industries
# News
# Hyland appoints Lubor Ptacek as Senior Vice President of Product Marketing
# Hyland advances its product narratives and go-to-market strategy, signaling a new phase of growth as the company fuels the agentic enterprise
# News
# Hyland to showcase the content-powered Agentic Enterprise at CommunityLIVE 2026
# The four‑day conference brings together 2,000+ content experts and industry leaders to explore how governance, automation, and AI turn enterprise complexity into agentic business outcomes
# News
# Garney expands its use of Hyland OnBase to accelerate HR transformation
# Hyland OnBase and Hyland for SAP SuccessFactors enables Garney to modernize, automate and scale its HR content infrastructure
# All Hyland news
# Empower your people to deliver their best with Hyland
# Connect with an expert
# Get in touch
# Thank you!
# We have received your message and will be in contact shortly.
# Thank you!
# We have received your message and will be in contact shortly.
# Be more informed, empowered and connected through every interaction
# and in every relationship with everyone you serve.
# Contact us
# Why Hyland
# Case Studies
# Analyst Reports
# Insights
# Integrations
# Discover & Learn
# Resource Center
# Terminology
# Downloads
# Product Updates
# All Pages
# Hyland Services
# Implementation
# Managed
# Consulting
# Data Conversion
# About Hyland
# Careers
# About
# Partners
# Corporate Responsibility
# Newsroom
# Connect
# Community
# Events
# Training
# Documentation
# Tech Support
# Start your shift to a new era of content innovation.
# Get monthly insights
# Follow Us
# ©2026 Hyland. All rights reserved.
# Hyland, the H design, and Hyland product names are registered and/or unregistered trademarks of Hyland and its affiliates in the United States and other countries.
# Privacy
# Cookie Policy
# Manage Cookies
# Do Not Sell or Share My Personal Information
# Terms of Use
# Security and Compliance
# Legal and Compliance

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content
# Out:
# '2 + 2 equals 4.'

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': "\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nHyland  | Content Services | Enterprise Content Management\nSkip to content\nCommunity\nContact us\nEnglish\nEN\nPortuguês\nPT\nEnglish\nEN\nFrançais\nFR\nDeutsch\nDE\n日本語\n日本語\nEspañol\nES\nSearch\nToggle mobile navigation\nSearch\nPLATFORM\nPLATFORM\nPlatform\nEnterprise AI\nAgentic Document Processing\nProcess Automation\nContent Management\nDigital Asset Management\nGovernance\nApplication Development\nSystems Integrations\nCollaboration\nCloud\nPLATFORM\nContent Innovation Cloud™\nHarness the power of a unified content, process and application intelligence platform to unlock the value of enterprise content.\nLearn more\nEnterprise AI\nAgentic Document Processing\nProcess Automation\nContent Management\nDigital Asset Management\nInsert your title here\nGovernance\nApplication Development\nInsert your title here\nSystems Integrations\nCollaboration\nInsert your title here\nCloud\nClose menu\nSOLUTIONS\nSOLUTIONS\nSolutions Overview\nBy Industry\nBy Department\nServices\nTechnical Support\nAll Products\nSOLUTIONS\nIntelligent document processing\nAutomate your document-centric processes with AI-powered document capture, separation, classification, extraction and enrichment.\nLearn about Hyland IDP\nBy Industry\nIndustries Overview\nHealthcare\nFinancial Services\nGovernment\nInsurance\nEducation\nMedia & Entertainment\nManufacturing\nCPG & Retail\nOther Industries\nIndustries\nIt's your unique digital evolution … but you don't have to face it alone. We understand the landscape of your industry and the unique needs of the people you serve.\nOverview of industries\nBy Department\nDepartments Overview\nAccounting & Finance\nHuman Resources\nLegal\nDepartments\nCountless teams and departments have transformed the way they work in accounting, HR, legal and more with Hyland solutions.\nOverview of departments\nServices\nServices Overview\nEducation Services\nImplementation Services\nManaged Services\nConsulting Services\nData Conversion Services\nServices\nWe are committed to helping you maximize your technology investment so you can best serve your customers.\nOverview of services\nTechnical Support\nInsert your title here\nAll Products\nClose menu\nCUSTOMERS\nCUSTOMERS\nCustomers Overview\nCase Studies\nCUSTOMERS\nCommunityLIVE 2026\nGet ready to take your knowledge of AI, enterprise agents and intelligent automation to the next level.\nRegister now\nCase Studies\nClose menu\nPARTNERS\nPARTNERS\nPartner Program\nBecome a Partner\nFind a Partner\nPartner Resources\nPARTNERS\nPartners\nOur exclusive partner programs combine our strengths with yours to create better experiences through content services.\nOverview of partners\nBecome a Partner\nFind a Partner\nPartner Resources\nClose menu\nRESOURCES\nRESOURCES\nResources Overview\nAnalyst Reports\nArticles\nDownloads\nEvents\nProduct Releases\nTerminology\nWebinars\nResource Center\nRESOURCES\nGet monthly insights\nJoin The Shift newsletter for the latest strategies and expert tips from industry leaders. Discover actionable steps to stay innovative.\nRegister now\nAnalyst Reports\nArticles\nArticles\nDownloads\nEvents\nProduct News\nTerminology\nWebinars\nResource Center\nClose menu\nCOMPANY\nCOMPANY\nOverview of Hyland\nAbout\nWhy Hyland?\nNewsroom\nCareers\nCOMPANY\nCompany\nHyland connects your content and systems so you can forge stronger connections with the people who matter most.\nLearn about Hyland\nAbout\nAbout Overview\nHistory\nCorporate Responsibility\nAcquisitions\nExecutive Team\nLocations\nAwards and accolades\nWhy choose Hyland?\nWith our modern, open and cloud-native platforms, you can build strong connections and keep evolving.\nDig deeper\nWhy Hyland?\nNewsroom\nCareers\nClose menu\nRequest a demo\nUnlock the\npower\nof your content\nConnect your enterprise content with our AI-enabled solutions — deliver ...

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# '# Snarky Summary of Edward Donner’s Website\n\nWelcome to the digital playground of Edward, a self-confessed LLM-obsessed code monkey who turned his endless AI rants from annoying his friends into a half-million-student Udemy empire. When he’s not busy creating AI courses that make everyone look smarter, he’s moonlighting as CTO of Nebula.io, where AI actually tries to *help* people discover their life’s purpose (because the world really needed *another* purpose-finding app). \n\nNoteworthy newsflash: Ed keeps updating his AI engineering curriculum with fresh resources all the way through 2026—because apparently, the future never stops coming. Plus, there’s an arena called "Outsmart," where large language models fight it out in diplomatic battles. Who knew AI could have passive-aggressive Twitter spats?\n\nSo, if you want to geek out on AI, watch LLMs bicker, or steal some coding wisdom from the guy who somehow made AI courses fun-ish, this is your stop. Also, brace yourself for extremely amateur electronic music references and lots of nodding sagely at Hacker News.\n\n**Latest Drops:**\n- Feb 2026: From Vibe Coder to Agentic Engineer resources\n- Jan 2026: Build AI Agents with n8n, including voice agents\n- Sept 2025: Deploy AI to production MLOps track\n- May 2025: Course order guide (because AI learning should have a GPS)\n\nNeed to complain or geek out? Ed’s just an email away.'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://hyland.com")
# Out:
# # Hyland: The Overachiever of Enterprise Content Services
#
# Welcome to Hyland, where your boring stacks of enterprise content get zapped into intelligent, automated, and AI-powered gold. They’ve got a fancy Content Innovation Cloud™ that makes your unstructured data *actually useful* — because apparently, your digital chaos needs a hero.
#
# ## What They Do
# - AI-driven document processing that basically *does your paperwork for you*.
# - Automation everywhere — workflows, content management, governance, even app-building and integrations.
# - Industry-specific magic from healthcare to retail, financial services to government. They basically have a solution for everyone (even your weird niche industry).
# - Cloud-native platform with all the security, compliance, and scalability buzzwords, so you know your data is “safe.”
#
# ## Customer Bragging Rights
# More than half of the Fortune 100 are customers, which is the corporate equivalent of being invited to the cool kids' table. L’Oréal, Liberty Mutual, Toyota Financial Services—they all swear by Hyland’s mojo.
#
# ## Latest Gossip from the Newsroom
# - Hyland just dropped new AI tricks to turn content chaos into “agentic” enterprise action (fancy talk for smarter automation).
# - They welcomed Lubor Ptacek as their new Senior VP of Product Marketing — probably to make all these buzzwords sound even cooler.
# - Promoting their CommunityLIVE 2026 conference where 2,000+ nerds will geek out on AI, governance, and automation.
# - Case study highlight: Garney is speeding up their HR transformation with Hyland’s tools because who likes slow HR?
#
# ## TL;DR
# Hyland is like your overachieving tech-savvy friend who organizes your life, automates your chores, and throws in AI-powered analytics for dessert—all to make enterprise content less of a headache and more of a business asset. If you handle mountains of data and documents, Hyland’s your new BFF.
